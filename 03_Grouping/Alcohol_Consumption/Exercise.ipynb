# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.groupby('continent').agg({'beer_servings':'mean'}).reset_index().sort_values('beer_servings',ascending=False)
# Out:
#   continent  beer_servings
# 2        EU     193.777778
# 4        SA     175.083333
# 3        OC      89.687500
# 0        AF      61.471698
# 1        AS      37.045455

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby('continent').agg({'wine_servings':'describe'}).reset_index()
# Out:
#   continent wine_servings                                                   \
#                     count        mean        std  min   25%    50%     75%
# 0        AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00
# 1        AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00
# 2        EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00
# 3        OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25
# 4        SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50
#
#
#      max
# 0  233.0
# 1  123.0
# 2  370.0
# 3  212.0
# 4  221.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
drinks.set_index('continent').select_dtypes(include=[np.number]).groupby(level=0).mean().reset_index()
# Out:
#   continent  beer_servings  spirit_servings  wine_servings  \
# 0        AF      61.471698        16.339623      16.264151
# 1        AS      37.045455        60.840909       9.068182
# 2        EU     193.777778       132.555556     142.222222
# 3        OC      89.687500        58.437500      35.625000
# 4        SA     175.083333       114.750000      62.416667
#
#    total_litres_of_pure_alcohol
# 0                      3.007547
# 1                      2.170455
# 2                      8.617778
# 3                      3.381250
# 4                      6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.set_index('continent').select_dtypes(include=[np.number]).groupby(level=0).median().reset_index()
# Out:
#   continent  beer_servings  spirit_servings  wine_servings  \
# 0        AF           32.0              3.0            2.0
# 1        AS           17.5             16.0            1.0
# 2        EU          219.0            122.0          128.0
# 3        OC           52.5             37.0            8.5
# 4        SA          162.5            108.5           12.0
#
#    total_litres_of_pure_alcohol
# 0                          2.30
# 1                          1.20
# 2                         10.00
# 3                          1.75
# 4                          6.85

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
drinks.groupby('continent').agg({'spirit_servings':['mean','min','max']}).reset_index()
# Out:
#   continent spirit_servings
#                        mean min  max
# 0        AF       16.339623   0  152
# 1        AS       60.840909   0  326
# 2        EU      132.555556   0  373
# 3        OC       58.437500   0  254
# 4        SA      114.750000  25  302
