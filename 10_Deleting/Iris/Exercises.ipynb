# %% [markdown]
# # Iris

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
iris = pd.read_csv(url,
                   header=None,
                   sep=',')
iris.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

iris.columns = ['1. sepal_length (in cm)',
                '2. sepal_width (in cm)',
                '3. petal_length (in cm)',
                '4. petal_width (in cm)',
                '5. class',]
iris.head()
# Out:
#    1. sepal_length (in cm)  2. sepal_width (in cm)  3. petal_length (in cm)  \
# 0                      5.1                     3.5                      1.4
# 1                      4.9                     3.0                      1.4
# 2                      4.7                     3.2                      1.3
# 3                      4.6                     3.1                      1.5
# 4                      5.0                     3.6                      1.4
#
#    4. petal_width (in cm)     5. class
# 0                     0.2  Iris-setosa
# 1                     0.2  Iris-setosa
# 2                     0.2  Iris-setosa
# 3                     0.2  Iris-setosa
# 4                     0.2  Iris-setosa

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   1. sepal_length (in cm)  150 non-null    float64
#  1   2. sepal_width (in cm)   150 non-null    float64
#  2   3. petal_length (in cm)  150 non-null    float64
#  3   4. petal_width (in cm)   150 non-null    float64
#  4   5. class                 150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.loc[10:29,'3. petal_length (in cm)'] = pd.NA
iris.loc[9:30,:]
# Out:
#     1. sepal_length (in cm)  2. sepal_width (in cm)  3. petal_length (in cm)  \
# 9                       4.9                     3.1                      1.5
# 10                      5.4                     3.7                      NaN
# 11                      4.8                     3.4                      NaN
# 12                      4.8                     3.0                      NaN
# 13                      4.3                     3.0                      NaN
# 14                      5.8                     4.0                      NaN
# 15                      5.7                     4.4                      NaN
# 16                      5.4                     3.9                      NaN
# 17                      5.1                     3.5                      NaN
# 18                      5.7                     3.8                      NaN
# 19                      5.1                     3.8                      NaN
# 20                      5.4                     3.4                      NaN
# 21                      5.1                     3.7                      NaN
# 22                      4.6                     3.6                      NaN
# 23                      5.1                     3.3                      NaN
# 24                      4.8                     3.4                      NaN
# 25                      5.0                     3.0                      NaN
# 26                      5.0                     3.4                      NaN
# 27                      5.2                     3.5                      NaN
# 28                      5.2                     3.4                      NaN
# 29                      4.7                     3.2                      NaN
# 30                      4.8                     3.1                      1.6
#
#     4. petal_width (in cm)     5. class
# 9                      0.1  Iris-setosa
# 10                     0.2  Iris-setosa
# 11                     0.2  Iris-setosa
# 12                     0.1  Iris-setosa
# 13                     0.1  Iris-setosa
# 14                     0.2  Iris-setosa
# 15                     0.4  Iris-setosa
# 16                     0.4  Iris-setosa
# 17                     0.3  Iris-setosa
# 18                     0.3  Iris-setosa
# 19                     0.3  Iris-setosa
# 20                     0.2  Iris-setosa
# 21                     0.4  Iris-setosa
# 22                     0.2  Iris-setosa
# 23                     0.5  Iris-setosa
# 24                     0.2  Iris-setosa
# 25                     0.2  Iris-setosa
# 26                     0.4  Iris-setosa
# 27                     0.2  Iris-setosa
# 28                     0.2  Iris-setosa
# 29                     0.2  Iris-setosa
# 30                     0.2  Iris-setosa

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris.fillna(1.0, inplace=True)
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   1. sepal_length (in cm)  150 non-null    float64
#  1   2. sepal_width (in cm)   150 non-null    float64
#  2   3. petal_length (in cm)  150 non-null    float64
#  3   4. petal_width (in cm)   150 non-null    float64
#  4   5. class                 150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
iris.drop('5. class', inplace=True, axis=1)

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.loc[:2,:] = pd.NA
iris.head()
# Out:
#    1. sepal_length (in cm)  2. sepal_width (in cm)  3. petal_length (in cm)  \
# 0                      NaN                     NaN                      NaN
# 1                      NaN                     NaN                      NaN
# 2                      NaN                     NaN                      NaN
# 3                      4.6                     3.1                      1.5
# 4                      5.0                     3.6                      1.4
#
#    4. petal_width (in cm)
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     0.2
# 4                     0.2

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris.dropna(inplace=True,
            axis=0,
            how='any')

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index(drop=True)
# Out:
#      1. sepal_length (in cm)  2. sepal_width (in cm)  3. petal_length (in cm)  \
# 0                        4.6                     3.1                      1.5
# 1                        5.0                     3.6                      1.4
# 2                        5.4                     3.9                      1.7
# 3                        4.6                     3.4                      1.4
# 4                        5.0                     3.4                      1.5
# ..                       ...                     ...                      ...
# 142                      6.7                     3.0                      5.2
# 143                      6.3                     2.5                      5.0
# 144                      6.5                     3.0                      5.2
# 145                      6.2                     3.4                      5.4
# 146                      5.9                     3.0                      5.1
#
#      4. petal_width (in cm)
# 0                       0.2
# 1                       0.2
# 2                       0.4
# 3                       0.3
# 4                       0.2
# ..                      ...
# 142                     2.3
# 143                     1.9
# 144                     2.0
# 145                     2.3
# 146                     1.8
#
# [147 rows x 4 columns]

# %% [markdown]
# ### BONUS: Create your own question and answer it.
